# %%
import numpy as np
import matplotlib.pyplot as plt
import LDP.basicFunction.basicfunc as bf

# %%
n=10000000#用户数

# %%
## uniform
uniform_k=np.random.uniform(1,1000,1000000)
uniform_v=np.random.uniform(-1,1,1000000)
uniform_v
# Out:
# array([ 0.71223819,  0.96907001, -0.2280712 , ..., -0.50511576,
#         0.02188049,  0.96681962])

# %%
plt.hist(uniform_k)
plt.hist(uniform_v)
plt.show()

# %%
k=np.round(uniform_k)
k.tolist()
# Out:
# [901.0,
#  262.0,
#  419.0,
#  851.0,
#  152.0,
#  757.0,
#  608.0,
#  969.0,
#  660.0,
#  525.0,
#  39.0,
#  342.0,
#  211.0,
#  89.0,
#  540.0,
#  603.0,
#  149.0,
#  787.0,
#  502.0,
#  995.0,
#  876.0,
#  135.0,
#  200.0,
#  253.0,
#  408.0,
#  664.0,
#  885.0,
#  794.0,
#  650.0,
#  719.0,
#  568.0,
#  321.0,
#  804.0,
#  621.0,
#  228.0,
#  353.0,
#  369.0,
#  914.0,
#  878.0,
#  855.0,
#  143.0,
#  738.0,
#  315.0,
#  505.0,
#  455.0,
#  58.0,
#  157.0,
#  896.0,
#  160.0,
#  975.0,
#  526.0,
#  748.0,
#  624.0,
#  880.0,
#  585.0,
#  340.0,
#  231.0,
#  103.0,
#  800.0,
#  936.0,
#  744.0,
#  185.0,
#  864.0,
#  100.0,
#  887.0,
#  442.0,
#  944.0,
#  130.0,
#  827.0,
#  161.0,
#  511.0,
#  186.0,
#  974.0,
#  697.0,
#  509.0,
#  655.0,
#  621.0,
#  602.0,
#  691.0,
#  105.0,
#  806.0,
#  279.0,
#  312.0,
#  767.0,
#  630.0,
#  432.0,
#  263.0,
#  934.0,
#  464.0,
#  107.0,
#  758.0,
#  760.0,
#  993.0,
#  668.0,
#  24.0,
#  307.0,
#  731.0,
#  222.0,
#  331.0,
#  893.0,
# ...

# %%
v=uniform_v
v.tolist()
# Out:
# [0.7122381938581797,
#  0.9690700057559922,
#  -0.22807120205154296,
#  0.01740781758502341,
#  0.4082845093241061,
#  0.8616779286326803,
#  -0.10345454166847756,
#  -0.4294238658701597,
#  -0.12436878599310419,
#  0.5821495940484556,
#  -0.196103424873179,
#  0.8618713206608419,
#  0.8923553117361576,
#  -0.9827711586190309,
#  -0.11803462735718973,
#  0.8265115747573901,
#  -0.9567566427349554,
#  0.13352030946194415,
#  -0.38240997158130186,
#  0.7354095968911776,
#  0.013720150894346528,
#  -0.8104913096481263,
#  -0.8734889936198704,
#  -0.17645757307033905,
#  0.38100643271980683,
#  0.676656863733744,
#  -0.2214252185168364,
#  -0.6873288889976632,
#  0.39226208921185757,
#  -0.6848657865507601,
#  0.5822222575529756,
#  0.9412367303902325,
#  0.9345748679780885,
#  -0.14810406744251337,
#  0.05728718272948785,
#  -0.4340757783057174,
#  0.9503408990377002,
#  0.15704633501642218,
#  0.8375467317247121,
#  -0.8976469387833041,
#  -0.4658019689758732,
#  0.35278380261977604,
# ...

# %%
kv=list(zip(k,v))
kv
# Out:
# [(901.0, 0.71223819385817966),
#  (262.0, 0.96907000575599223),
#  (419.0, -0.22807120205154296),
#  (851.0, 0.017407817585023411),
#  (152.0, 0.40828450932410609),
#  (757.0, 0.86167792863268033),
#  (608.0, -0.10345454166847756),
#  (969.0, -0.42942386587015968),
#  (660.0, -0.12436878599310419),
#  (525.0, 0.58214959404845557),
#  (39.0, -0.196103424873179),
#  (342.0, 0.86187132066084193),
#  (211.0, 0.89235531173615756),
#  (89.0, -0.98277115861903086),
#  (540.0, -0.11803462735718973),
#  (603.0, 0.82651157475739012),
#  (149.0, -0.95675664273495542),
#  (787.0, 0.13352030946194415),
#  (502.0, -0.38240997158130186),
#  (995.0, 0.73540959689117757),
#  (876.0, 0.013720150894346528),
#  (135.0, -0.81049130964812632),
#  (200.0, -0.87348899361987042),
#  (253.0, -0.17645757307033905),
#  (408.0, 0.38100643271980683),
#  (664.0, 0.67665686373374401),
#  (885.0, -0.22142521851683639),
#  (794.0, -0.6873288889976632),
#  (650.0, 0.39226208921185757),
# ...

# %%
# bf.savetxt(k,'../MLPKV/data/Uniform_d/Uniform_d_k.txt')
# bf.savetxt(v,'../MLPKV/data/Uniform_d/Uniform_d_v.txt')
# bf.savetxt(kv,'../MLPKV/data/Uniform_d/Uniform_d_kv.txt')
# Out:
# 保存文件成功
# 保存文件成功
# 保存文件成功

# %%
gauss_k=np.random.normal(500,150,n)
gauss_v=np.random.normal(0,0.5,n)
gauss_k=np.round(gauss_k)
gauss_k
k=gauss_k[(gauss_k>=1)&(gauss_k<=1000)][:1000000]

max(k),min(k),len(k)
# Out:
# (1000.0, 1.0, 1000000)

# %%
v=gauss_v[(gauss_v>=-1)&(gauss_v<=1)][:1000000]
len(v),max(v),min(v)
# Out:
# (1000000, 0.99999846431733508, -0.99996340671064921)

# %%
kv=list(zip(k,v))

# %%
len(kv)
# Out:
# 954633

# %%
bf.savetxt(k,'../MLPKV/data/Gaussian_d/Gaussian_d_k.txt')
bf.savetxt(v,'../MLPKV/data/Gaussian_d/Gaussian_d_v.txt')
bf.savetxt(kv,'../MLPKV/data/Gaussian_d/Gaussian_d_kv.txt')
# Out:
# 保存文件成功
# 保存文件成功
# 保存文件成功
